# %% [markdown]
# # 1. 당장 좋은 것만 선택하는 그리디

# %% [markdown]
# ![코딩테스트_3.png](data:image/png;base64,...)

# %% [markdown]
# - 문제 해결의 아이디어
#     - '가장 큰 화폐단위부터' 돈을 거슬러 주는 것
#     - N원을 거슬러 줘야 할 때, 500원 -> 100원 -> 50원 -> 10원짜리 동전 순서대로 거슬러 준다.

# %% [markdown]
# ![코딩테스트_(2-2).png](data:image/png;base64,...)

# %% [markdown]
# ![코딩테스트_2-3.png](data:image/png;base64,...)

# %% [markdown]
# ![코딩테스트_2-4.png](data:image/png;base64,...)

# %% [markdown]
# ![코딩테스트_2-5.png](data:image/png;base64,...)

# %% [markdown]
# ![코딩테스트_2-6.png](data:image/png;base64,...)

# %%
n = 1260
count = 0

# 큰 단위의 화폐부터 차례대로 확인
coin_types = [500, 100, 50, 10]

for coin in coin_types:
    count += n // coin  # 해당 화폐로 거슬러 줄 수 있는 동전의 개수 세기
    n %= coin

print(count)
# Out:
# 6

# %% [markdown]
# - 화폐의 종류만큼 반복을 수행해야 함. => 화폐의 종류가 K개이면 시간 복잡도는 O(K)이다.
# - 알고리즘의 시간 복잡도는 동전의 총 종류에만 영향을 받고, 거슬러 줘야 할 금액의 크기와는 무관하다.
# - 실제 코딩테스트에서는 위 문제보다 난이도가 높지만 문제 접근 방법은 유사하므로 잘 익혀둔다.

# %% [markdown]
# ## 그리디 알고리즘의 정당성
# - 모든 알고리즘에 적용할 수는 없지만, **탐욕적으로 문제에 접근했을 때 정확한 답을 찾을 수 있는 문제**에서는 매우 효과적이고 직관적
# - 대부분의 그리디 알고리즘 문제에서는 문제 풀이를 위한 최소한의 아이디어를 떠올리고 이것이 정당한지 검토할 수 있어야 답을 도출할 수 있다.
# - 만약 오랜 시간을 고민해도 그리디 알고리즘으로 해결 방법을 찾을 수 없다면, 다이나믹 프로그래밍이나 그래프 알고리즘 등으로 문제를 해결할 수 있는지 재차 고민해본다.
