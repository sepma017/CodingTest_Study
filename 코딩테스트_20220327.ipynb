# %% [markdown]
# # 더 알아두면 좋은 알고리즘

# %% [markdown]
# ## 소수의 판별(1)

# %% [markdown]
# - 소수(Prime Number) : 2보다 큰 자연수 중에서 1과 자기 자신을 제외한 자연수로는 나누어 떨어지지 않는 자연수
# - 코딩테스트에서 어떤 자연수가 소수가 아닌지 판별해야 하는 경우가 생긴다. 또는 1부터 N까지의 모든 소수를 출력해야 하는 문제 등이 출제될 수 있다.
# - 어떤 수 X가 주어졌을 때 해당 수가 소수인지 아닌지 판별하는 가장 간단한 방법은 X를 2부터 X-1까지의 모든 수로 나누어 보는 것
#     - 만약 2부터 X-1까지의 모든 자연수로 나누었을 때 나누어떨어지는 수가 하나라도 존재하면 X는 소수가 아니다.

# %%
# 소수 판별 함수
def is_prime_number(x):
    # 2부터 (x - 1)까지의 모든 수를 확인하며
    for i in range(2, x):
        # x가 해당 수로 나누어떨어진다면
        if x % i == 0:
            return False    # 소수가 아님
    return True     # 소수임

print(is_prime_number(4))
print(is_prime_number(7))
# Out:
# False
# True

# %% [markdown]
# - 코드의 실행 결과는 차례대로 False, True 인 것을 확인할 수 있다.
# - 알고리즘의 시간 복잡도는 O(X)이다. => 비효율적
# - 이 알고리즘을 개선해서 하나의 수가 소수인지 판별하는 알고리즘을 O(X)보다 더 빠르게 동작하도록 작성할 수 있다.
# - 자연수의 약수가 가지는 특성을 파악하고 있다면 그 원리를 쉽게 이해할 수 있다.
# - 예) 16의 약수(Divisor) : 1, 2, 4, 8, 16
# - 모든 약수에 대하여, 가운데 약수를 기준으로 하여 대칭적으로 2개씩 앞뒤로 묶어서 곱하면 16을 만들 수 있다.

# %% [markdown]
# ![코딩테스트_3-1.png](data:image/png;base64,...)

# %% [markdown]
# - 결과적으로 다음 5개의 등식이 성립하는 것을 확인할 수 있다.

# %% [markdown]
# ![코딩테스트_3-2.png](data:image/png;base64,...)

# %% [markdown]
# - 여기서 알 수 있는 점은 가운데 약수를 기준으로 해서 각 등식이 대칭적인 형태를 보인다는 것이다.
# - 예) 2 x 8 = 16은 8 x 2 = 16과 대칭
# - 특정한 자연수 X가 소수인지 확인하기 위하여 바로 가운데 약수까지만 '나누어떨어지는지'확인하면 된다. => 위 예시에서는 4까지만 확인하면 됨.
# - 제곱근까지만 (가운데 약수까지만) 확인하면 된다
# - 예) 8의 약수 : 1, 2, 4, 8
#     - 약수를 앞뒤로 2개씩 묶으면 다음과 같다.
#         - 1 x 8 = 8
#         - 2 x 4 = 8
#         - 4 x 2 = 8
#         - 8 x 1 = 8
# - 8도 8의 제곱근까지만 확인하면 된다.
# - 8의 제곱근이 2.828...이므로 2까지만 확인한다. (3부터는 확인할 필요 없다.)
# - 시간복잡도를 O($X^{1/2}$)에 소수를 판별할 수 있다.

# %%
import math

# 소수 판별 함수
def is_prime_number(x):
    # 2부터 x의 제곱근까지의 모든 수를 확인하며
    for i in range(2, int(math.sqrt(x)) + 1):
        # x가 해당 수로 나누어떨어진다면
        if x % i == 0:
            return False    # 소수가 아님
    return True     # 소수임

print(is_prime_number(4))
print(is_prime_number(7))
# Out:
# False
# True
