# %% [markdown]
# # 3. 숫자 카드 게임
# - 여러 개의 숫자 카드 중에서 가장 높은 숫자가 쓰인 카드 한 장을 뽑는 게임
# - 단, 게임의 룰을 지키며 카드를 뽑아야 함. 룰은 아래와 같음.
#     - 1. 숫자가 쓰인 카드들이 N x M 형태로 놓여 있다. N은 행의 개수, M은 열읙 개수
#     - 2. 먼저 뽑고자 하는 카드가 포함되어 있는 행을 선택한다.
#     - 3. 그다음 선택된 행에 포함된 카드들 중 가장 숫자가 낮은 카드를 뽑아야 한다.
#     - 4. 따라서 처음에 카드를 골라낼 행을 선택할 때, 이후에 해당 행에서 가장 숫자가 낮은 카드를 뽑을 것을 고려하여 최종적으로 가장 높은 숫자의 카드를 뽑을 수 있도록 전략을 세워야 한다.

# %% [markdown]
# - 예를 들어 3 x 3 형태로 카드들이 놓여 있을 때,

# %% [markdown]
# ![코딩테스트_2-10.png](data:image/png;base64,...)

# %% [markdown]
# - 여기서 카드를 골라낼 행을 고를 때, 첫 번째 혹은 두 번째 행을 선택하는 경우, 최종적으로 뽑는 카드는 1이나 세 번째 행을 선택할 경우 최종적으로 뽑는 카드는 2이다. => 세 번째 행을 선택하여 2를 뽑는 것이 정답

# %% [markdown]
# ![코딩테스트_2-11.png](data:image/png;base64,...)

# %% [markdown]
# ### 문제 해설
# - 그리디 알고리즘 문제 => 문제 해결을 위한 아이디어가 떠오르면 정답을 찾을 수 있다.
# - 아이디어: **각 행마다 가장 작은 수를 찾은 뒤에 그 수 중에서 가장 큰 수**를 찾는 것
# - 설명이 길어서 지문 이해 시간이 많이 소요되나, 문제 해결 아이디어 떠올리는 것은 쉬운 문제
# - 입력 조건에서 입력으로 들어오는 수는 모두 10,000이하 => 배열에서 가장 작은 수를 찾는 기본 문법을 이용하여 각 행에서 가장 작은 수를 찾은 다음 그 수 중에서 가장 큰 수를 찾는 방법으로 해결가능.
# - min() 함수 이용할 수 있거나 또는 2중 반목문 구조를 이용할 수 있어야 함.

# %%
# min() 함수를 이용하는 답안 예시

# N, M을 공백으로 구분하여 입력받기
n, m = map(int, input().split())

result = 0
# 한 줄씩 입력받아 확인
for i in range(n):
    data = list(map(int, input().split()))
    # 현재 줄에서 '가장 작은 수' 찾기
    min_value = min(data)
    # '가장 작은 수'들 중에서 가장 큰 수 찾기
    result = max(result, min_value)

print(result)   # 최종 답안 출력
# Out:
# 3 3
# 3 1 2
# 4 1 4
# 2 2 2
# 2

# %%
# 2중 반복문 구조를 이용하는 답안 예시

# N, M을 공백으로 구분하여 입력받기
n, m = map(int, input().split())

result = 0
# 한 줄씩 입력받아 확인
for i in range(n):
    data = list(map(int, input().split()))
    # 현재 줄에서 '가장 작은 수' 찾기
    min_value = 10001
    for a in data:
        min_value = min(min_value, a)
    # '가장 작은 수'들 중에서 가장 큰 수 찾기
    result = max(result, min_value)

print(result)   # 최종 답안 출력
# Out:
# 2 4
# 7 3 1 8
# 3 3 3 4
# 3
