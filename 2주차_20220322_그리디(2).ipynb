# %% [markdown]
# # 2. 큰 수의 법칙

# %% [markdown]
# ![코딩테스트_2-7.png](data:image/png;base64,...)

# %% [markdown]
# ### 문제 해설
# - 전형적인 그리디 알고리즘 문제
# - 문제 해결을 위한 아이디어 떠올리는 것은 쉬운 편, 구현 실수로 인한 오답 처리 받는 경우 많음 => 꼭 직접 코드를 작성해본다.
# - 해결법
#     - 일단 입력값 중에서 가장 큰 수와 두 번째로 큰 수만 저장한다. 연속으로 더할 수 있는 횟수는 최대 K번
#     - '가장 큰 수를 K번 더하고 두 번째로 큰 수를 한 번 더하는 연산' 반복

# %%
# 단순하게 푸는 답안 예시

# N, M, K를 공백으로 구분하여 입력받기
n, m, k = map(int, input().split())
# N개의 수를 공백으로 구분하여 입력받기
data = list(map(int, input().split()))

data.sort() # 입력받은 수를 정렬하기
first = data[n - 1] # 가장 큰 수
second = data[n - 2]    # 두 번째로 큰 수

result = 0

while True:
    for i in range(k):  # 가장 큰 수를 K번 더하기
        if m == 0 : # m이 0이라면 반복문 탈출
            break
        result += first
        m -= 1  # 더할 때마다 1씩 빼기
    if m == 0:  # m이 0이라면 반복문 탈출
        break
    result += second    # 두 번째로 큰 수를 한 번 더하기
    m -= 1  # 더할 때마다 1씩 빼기

print(result)   # 최종 답안 출력
# Out:
# 5 8 3
# 2 4 5 4 6
# 46

# %% [markdown]
# #### Tip
# - 파이썬에서 여러 데이터를 한꺼번에 입력받을 때는 list()와 map()을 이용한다.

# %% [markdown]
# - M이 10,000이하이므로 이 방식으로도 해결 가능. 그러나 M의 크기가 100억 이상이면 시간 초과 판정을 받을 수 있다. => 간단한 수학적 아이디어로 더 효율적으로 문제 해결!
# - N이 5이고 입력값은 아래와 같으면,

# %% [markdown]
# ![코딩테스트_2-8.png](data:image/png;base64,...)

# %% [markdown]
# - 가장 큰 수: 6
# - 두 번째로 큰 수: 5

# %% [markdown]
# - 이때, M이 8, K가 3이면 아래와 같이 더해 합을 최대로 할 수 있다.
# - (6+6+6+5) + (6+6+6+5) = 46

# %% [markdown]
# ![코딩테스트_2-9.png](data:image/png;base64,...)

# %% [markdown]
# - 문제를 해결하기 위한 방법
#     - 먼저 반복되는 수열에 대해서 파악한다.
#         - 예시: 수열 {6, 6, 6, 5} 반복
#     - 반복되는 수열의 길이를 찾는다. (K+1)
#         - 예시: 4
#     - 수열의 반복하는 횟수를 구한다. (M을 (K+1)로 나눈 몫)
#     - 횟수에 K를 곱해주면 가장 큰 수가 등장하는 횟수가 나온다.
#     - 이때, M이 (K+1)로 나누어떨어지지 않는 경우
#         - M을 (K+1)로 나눈 나머지만큼 가장 큰 수가 추가로 더해지므로 이를 고려해주어야 한다.

# %% [markdown]
# - 가장 큰 수가 더해지는 횟수
# ```
# int(M/(K+1)) * K + M % (K+1)
# ```

# %%
# N, M, K를 공백으로 구분하여 입력받기
n, m, k = map(int, input().split())
# N개의 수를 공백으로 구분하여 입력받기
data = list(map(int, input().split()))

data.sort() # 입력받은 수 정렬
first = data[n-1]   # 가장 큰 수
second = data[n-2]  # 두 번째로 큰 수

# 가장 큰 수가 더해지는 횟수 계산
count = int(m/(k+1)) * k
count += m % (k+1)

result = 0
result += (count) * first   # 가장 큰 수 더하기
result += (m - count) * second  # 두 번째로 큰 수 더하기

print(result)   # 최종 답안 출력
# Out:
# 5 8 3
# 2 4 5 4 6
# 46
