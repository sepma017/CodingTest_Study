# %% [markdown]
# # 2. 왕실의 나이트

# %% [markdown]
# ![코딩테스트_3-17.png](data:image/png;base64,...)

# %% [markdown]
# ![코딩테스트_3-18.png](data:image/png;base64,...)

# %% [markdown]
# ![코딩테스트_3-16.png](data:image/png;base64,...)

# %% [markdown]
# ### 문제 해설
# - 앞서 다룬 예제 '상하좌우'문제와 유사하다.
# - 나이트가 이동할 수 있는 경로를 하나씩 확인하여 이동하면 된다.
# - 8 x 8 좌표 평면을 벗어나지 않도록 꼼꼼하게 검사하는 과정이 필요하다.
# - 나이트의 이동 경로를 steps 변수에 넣는다면, 이 2가지 규칙에 따라 steps = [(-2,-1), (-1, -2), (2, -1), (2, 1), (1, 2), (-1, 2), (-2, 1)]로 값을 대입할 수 있다.
# - 현재 위치를 기준으로 아래쪽과 오른쪽은 양수, 위쪽과 왼쪽은 음수 값을 대입한 결과이다.
# - 나이트의 현재 위치가 주어지면 현재 위치에서 이동 경로를 더한 다음, 8 x 8 좌표 평면에 있는지 확인하면 된다. => 반복문으로 처리 가능
# - 좀 더 까다롭게 문제를 출제한다면? => 입력 문자가 열과 행이 아닌 1a와 같은 행과 열 형태로 들어왔을 때의 예외 처리를 요구할 수도 있다. (다양한 구현 유형에 대비하기 위해서는 파이썬 문법을 자유롭게 사용할 수 있도록 훈련하는 것이 중요하다.)
# - 답안 예시에서는 나이트를 이동할 수 있는 경로를 steps 변수에 하나씩 담은 것을 확인할 수 있다. (8가지 경우의 수를 반복문을 이용하여 하나씩 검사한다.)

# %%
## 답안 예시

# 현재 나이트의 위치 입력받기
input_data = input()
row = int(input_data[1])
column = int(ord(input_data[0])) - int(ord('a')) + 1

# 나이트가 이동할 수 있는 8가지 방향 정의
steps = [(-2, -1), (-1, -2), (2, -1), (2, 1), (1, 2), (-1, 2), (-2, 1)]

# 8가지 방향에 대하여 각 위치로 이동이 가능한지 확인
result = 0
for step in steps:
    # 이동하고자 하는 위치 확인
    next_row = row + step[0]
    next_column = column + step[1]
    # 해당 위치로 이동이 가능하면 카운트 증가
    if next_row >= 1 and next_row <= 8 and next_column >= 1 and next_column <= 8:
        result += 1

print(result)
# Out:
# a1
# 2

# %% [markdown]
# - 앞서 '상하좌우'문제에서는 dx, dy 리스트를 선언하여 이동할 방향을 기록할 수 있도록 했다.
# - 이번 소스코드에서는 steps 변수가 dx, dy 변수의 기능을 대신하여 수행한다.
# - 두 가지 형태 모두 자주 사용되므로 참고한다.
